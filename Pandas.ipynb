# %% [markdown]
# <a href="https://colab.research.google.com/github/MelKanyi/Data-Analysis/blob/master/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Load the panda files into the database:
import pandas as pd
#Load the numpy files into the database:
import numpy as np

# %%
Geo = pd.read_csv('cells_geo.csv', delimiter = ';')
Geo
# Out:
#       Unnamed: 0       VILLES  ...     CELL_ID   SITE_CODE
# 0              0       ADJAME  ...  fbb2e75af3  0bb492ef17
# 1              1       ADJAME  ...  1502501d78  0bb492ef17
# 2              2       ADJAME  ...  0c2e182a0c  0bb492ef17
# 3              3      ASSINIE  ...  69bdfc69fd  8a1e6ce31f
# 4              4      ASSINIE  ...  7a1029d2ab  8a1e6ce31f
# 5              5      ASSINIE  ...  0b4f56438f  8a1e6ce31f
# 6              6     KRIKOREA  ...  041d2504f5  260dbfedc5
# 7              7        ABOBO  ...  a70c1d263b  56306cc7ca
# 8              8        ABOBO  ...  e2d04ea883  56306cc7ca
# 9              9        ABOBO  ...  ee224cd27e  56306cc7ca
# 10            10        ABOBO  ...  107d0d752c  56306cc7ca
# 11            11        ABOBO  ...  3f766cedc0  c1ccd3443b
# 12            12        ABOBO  ...  b0578cdb7f  c1ccd3443b
# 13            13        ABOBO  ...  18a4221316  c1ccd3443b
# 14            14        ABOBO  ...  1b2bccad1f  c1ccd3443b
# ...

# %%
Geo_description = pd.read_excel('cells_geo_description.xlsx', delimmiter = ';')
Geo_description
# Out:
#      Column name                                        Description  Format
# 0         VILLES                                               City  String
# 1         STATUS                                  In Service or not  String
# 2   LOCALISATION                                  in ABIDJAN or not  String
# 3     DECOUPZONE                                  Geographical Zone  String
# 4       ZONENAME                                       Name of Zone  String
# 5      LONGITUDE                                          Longitude   Float
# 6       LATITUDE                                           Latitude   Float
# 7         REGION                                             Region  String
# 8           AREA                                               Area  String
# 9        CELL_ID                                     ID of the cell  String
# 10     SITE_CODE  Site (there are several cells per site, severa...  String

# %%
CDR_description = pd.read_excel('CDR_description.xlsx', delimiter = ';')
CDR_description
# Out:
#        Column name                                        Description   Format
# 0          PRODUCT                                       Voice or SMS   String
# 1            VALUE                                      Billing price  Integer
# 2        DATE_TIME               Time in format yyyy-MM-dd hh:mm:ss.0   String
# 3     CELL_ON_SITE  Which cell in the site was used (not needed here)  Integer
# 4  DW_A_NUMBER_INT  Anonymized phone number of the person for whic...   String
# 5  DW_B_NUMBER_INT        Anonymized phone number of the counterparty   String
# 6        COUNTRY_A                  Country of party A (useless here)   String
# 7        COUNTRY_B                  Country of party B (useless here)   String
# 8          CELL_ID                                     ID of the cell   String
# 9          SITE_ID                                     ID of the SITE   String

# %%
# [http://bit.ly/TelecomDataset1]
CDR_507 = pd.read_csv('http://bit.ly/TelecomDataset1')
CDR_507
# Out:
#          PRODUTC  VALUE  ...     CELL_ID     SITE_ID
# 0          Voice      0  ...  /TJNe+Mmtu  /TJNe+Mmtu
# 1            sms      0  ...  /+cKZKIp41  /+cKZKIp41
# 2            sms     25  ...  /u0FSD+ahi  /u0FSD+ahi
# 3          Voice     56  ...  +cNeJzsTp3  +cNeJzsTp3
# 4          Voice     14  ...  051KhYDCpv  051KhYDCpv
# 5           data      0  ...  /lrUXVGVcN  /lrUXVGVcN
# 6          Voice      0  ...  +38u2u/rfx  +38u2u/rfx
# 7          Voice      0  ...  09UjmmY1Ds  09UjmmY1Ds
# 8          Voice      0  ...  0DeimCpZOc  0DeimCpZOc
# 9            sms      0  ...  01MDiY5F89  01MDiY5F89
# 10           sms      0  ...  0Fmr/IZtQ+  0Fmr/IZtQ+
# 11           sms      0  ...  0MZBLLzPYZ  0MZBLLzPYZ
# 12           sms      0  ...  0//cZOoEXj  0//cZOoEXj
# 13           sms     25  ...  2dmu2Iy1CX  2dmu2Iy1CX
# 14         Voice      0  ...  0Fmr/IZtQ+  0Fmr/IZtQ+
# 15         Voice      0  ...  176sGHv7Ym  176sGHv7Ym
# 16         Voice     44  ...  ++ctND+jGD  ++ctND+jGD
# ...

# %%
#http://bit.ly/TelecomDataset2
CDR_508 = pd.read_csv('http://bit.ly/TelecomDataset2')
CDR_508
# Out:
#          PRODUCT  VALUE  ...     CELL_ID     SITE_ID
# 0            sms      0  ...  +854AcBQT2  +854AcBQT2
# 1          Voice      0  ...  +854AcBQT2  +854AcBQT2
# 2            sms      0  ...  +laSrk7g6q  +laSrk7g6q
# 3          Voice     37  ...  /xvRrCVKoQ  /xvRrCVKoQ
# 4            sms     25  ...  +bO+qkSonO  +bO+qkSonO
# 5            sms      0  ...  /MMplBlWjh  /MMplBlWjh
# 6          Voice     41  ...  +laSrk7g6q  +laSrk7g6q
# 7          Voice     11  ...  +gySf02tKW  +gySf02tKW
# 8            sms      0  ...  /0FxP3az1x  /0FxP3az1x
# 9            sms      0  ...  0ecjmwPX21  0ecjmwPX21
# 10           sms      0  ...  +laSrk7g6q  +laSrk7g6q
# 11           sms      0  ...  /MMplBlWjh  /MMplBlWjh
# 12           sms      0  ...  +YzQI97cPp  +YzQI97cPp
# 13           sms      0  ...  +38u2u/rfx  +38u2u/rfx
# 14           sms      0  ...  0BRdojv2my  0BRdojv2my
# 15           sms      0  ...  +e+xcimwre  +e+xcimwre
# 16           sms      0  ...  +cNeJzsTp3  +cNeJzsTp3
# ...

# %%
#http://bit.ly/TelecomDataset3
CDR_509 = pd.read_csv('http://bit.ly/TelecomDataset3')
CDR_509
# Out:
#          PRODUCT  VALUE  ...      CELLID     SIET_ID
# 0          Voice     61  ...  +38u2u/rfx  +38u2u/rfx
# 1            sms      0  ...  +Fs4mTvdKx  +Fs4mTvdKx
# 2          Voice     10  ...  +ZaaZozy/+  +ZaaZozy/+
# 3            sms      0  ...  +cNeJzsTp3  +cNeJzsTp3
# 4          Voice     22  ...  /eeMklgyJA  /eeMklgyJA
# 5          Voice     10  ...  +e+xcimwre  +e+xcimwre
# 6            sms      0  ...  +R5ccmtyJf  +R5ccmtyJf
# 7          Voice     10  ...  +ZaaZozy/+  +ZaaZozy/+
# 8            sms     25  ...  13O1+JEun3  13O1+JEun3
# 9            sms      0  ...  /eeMklgyJA  /eeMklgyJA
# 10           sms      0  ...  /eeMklgyJA  /eeMklgyJA
# 11           sms      0  ...  /NPTR0H+5I  /NPTR0H+5I
# 12           sms      0  ...  18MlD9e2CO  18MlD9e2CO
# 13           sms      0  ...  0K+IDi1yjl  0K+IDi1yjl
# 14           sms      0  ...  2GgIN622rt  2GgIN622rt
# 15           sms     50  ...  051KhYDCpv  051KhYDCpv
# 16         Voice     14  ...  2aXXOLyR5M  2aXXOLyR5M
# ...

# %% [markdown]
# ##Previewing the Database

# %%
Geo = pd.read_csv('cells_geo.csv', delimiter = ';')
Geo.head(10)
# Out:
#    Unnamed: 0    VILLES      STATUS  ... AREA     CELL_ID   SITE_CODE
# 0           0    ADJAME  In Service  ...  NaN  fbb2e75af3  0bb492ef17
# 1           1    ADJAME  In Service  ...  NaN  1502501d78  0bb492ef17
# 2           2    ADJAME  In Service  ...  NaN  0c2e182a0c  0bb492ef17
# 3           3   ASSINIE  In Service  ...  NaN  69bdfc69fd  8a1e6ce31f
# 4           4   ASSINIE  In Service  ...  NaN  7a1029d2ab  8a1e6ce31f
# 5           5   ASSINIE  In Service  ...  NaN  0b4f56438f  8a1e6ce31f
# 6           6  KRIKOREA  In Service  ...  NaN  041d2504f5  260dbfedc5
# 7           7     ABOBO  In Service  ...  NaN  a70c1d263b  56306cc7ca
# 8           8     ABOBO  In Service  ...  NaN  e2d04ea883  56306cc7ca
# 9           9     ABOBO         NaN  ...  NaN  ee224cd27e  56306cc7ca
#
# [10 rows x 12 columns]

# %%
Geo_description = pd.read_excel('cells_geo_description.xlsx', delimiter = ';')
Geo_description.head(10)
# Out:
#     Column name        Description  Format
# 0        VILLES               City  String
# 1        STATUS  In Service or not  String
# 2  LOCALISATION  in ABIDJAN or not  String
# 3    DECOUPZONE  Geographical Zone  String
# 4      ZONENAME       Name of Zone  String
# 5     LONGITUDE          Longitude   Float
# 6      LATITUDE           Latitude   Float
# 7        REGION             Region  String
# 8          AREA               Area  String
# 9       CELL_ID     ID of the cell  String

# %%
CDR_description = pd.read_excel('CDR_description.xlsx', delimiter = ';')
CDR_description.head(10)
# Out:
#        Column name                                        Description   Format
# 0          PRODUCT                                       Voice or SMS   String
# 1            VALUE                                      Billing price  Integer
# 2        DATE_TIME               Time in format yyyy-MM-dd hh:mm:ss.0   String
# 3     CELL_ON_SITE  Which cell in the site was used (not needed here)  Integer
# 4  DW_A_NUMBER_INT  Anonymized phone number of the person for whic...   String
# 5  DW_B_NUMBER_INT        Anonymized phone number of the counterparty   String
# 6        COUNTRY_A                  Country of party A (useless here)   String
# 7        COUNTRY_B                  Country of party B (useless here)   String
# 8          CELL_ID                                     ID of the cell   String
# 9          SITE_ID                                     ID of the SITE   String

# %%
CDR_507.head(10)
# Out:
#   PRODUTC  VALUE               DATETIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0   Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1     sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2     sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3   Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4   Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
# 5    data      0  2012-05-06 23:07:26.0  ...     OTHER  /lrUXVGVcN  /lrUXVGVcN
# 6   Voice      0  2012-05-06 23:08:02.0  ...     19e2e  +38u2u/rfx  +38u2u/rfx
# 7   Voice      0  2012-05-06 23:08:03.0  ...     19e2e  09UjmmY1Ds  09UjmmY1Ds
# 8   Voice      0  2012-05-06 23:08:05.0  ...     19e2e  0DeimCpZOc  0DeimCpZOc
# 9     sms      0  2012-05-06 23:08:43.0  ...     19e2e  01MDiY5F89  01MDiY5F89
#
# [10 rows x 10 columns]

# %%
CDR_508.head(10)

# %%
CDR_509.head(10)
# Out:
#   PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B      CELLID     SIET_ID
# 0   Voice     61  2012-05-08 23:01:28.0  ...     19e2e  +38u2u/rfx  +38u2u/rfx
# 1     sms      0  2012-05-08 23:01:31.0  ...     19e2e  +Fs4mTvdKx  +Fs4mTvdKx
# 2   Voice     10  2012-05-08 23:02:59.0  ...     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 3     sms      0  2012-05-08 23:03:04.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4   Voice     22  2012-05-08 23:03:16.0  ...     19e2e  /eeMklgyJA  /eeMklgyJA
# 5   Voice     10  2012-05-08 23:03:59.0  ...     19e2e  +e+xcimwre  +e+xcimwre
# 6     sms      0  2012-05-08 23:06:06.0  ...     19e2e  +R5ccmtyJf  +R5ccmtyJf
# 7   Voice     10  2012-05-08 23:06:55.0  ...     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 8     sms     25  2012-05-08 23:07:09.0  ...     19e2e  13O1+JEun3  13O1+JEun3
# 9     sms      0  2012-05-08 23:07:38.0  ...     19e2e  /eeMklgyJA  /eeMklgyJA
#
# [10 rows x 10 columns]

# %% [markdown]
# ##Accessing Database Info

# %%
Geo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3974 entries, 0 to 3973
# Data columns (total 12 columns):
# Unnamed: 0      3974 non-null int64
# VILLES          3974 non-null object
# STATUS          3907 non-null object
# LOCALISATION    3974 non-null object
# DECOUPZONE      3974 non-null object
# ZONENAME        3968 non-null object
# LONGITUDE       3974 non-null float64
# LATITUDE        3974 non-null float64
# REGION          3974 non-null object
# AREA            3951 non-null object
# CELL_ID         3974 non-null object
# SITE_CODE       3974 non-null object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 372.6+ KB

# %%
Geo_description.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 3 columns):
# Column name    11 non-null object
# Description    11 non-null object
# Format         11 non-null object
# dtypes: object(3)
# memory usage: 344.0+ bytes

# %%
CDR_description.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
# Column name    10 non-null object
# Description    10 non-null object
# Format         10 non-null object
# dtypes: object(3)
# memory usage: 320.0+ bytes

# %%
CDR_507.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15011816 entries, 0 to 15011815
# Data columns (total 1 columns):
# PRODUTC,VALUE,DATETIME,CELL_ON_SITE,DW_A_NUMBER_INT,DW_B_NUMBER_INT,COUNTRY_A,COUNTRY_B,CELL_ID,SITE_ID    object
# dtypes: object(1)
# memory usage: 114.5+ MB

# %%
CDR_508.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19606112 entries, 0 to 19606111
# Data columns (total 1 columns):
# PRODUCT,VALUE,DATE_TIME,CELL_ON_SITE,DW_A_NUMBER,DW_B_NUMBER,COUNTRY_A,COUNTRY_B,CELL_ID,SITE_ID    object
# dtypes: object(1)
# memory usage: 149.6+ MB

# %%
CDR_509.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14834801 entries, 0 to 14834800
# Data columns (total 1 columns):
# PRODUCT,VALUE,DATE_TIME,CELL_ON_SITE,DW_A_NUMBER_INT,DW_B_NUMBER_INT,COUNTRY_A,COUNTRY_B,CELLID,SIET_ID    object
# dtypes: object(1)
# memory usage: 113.2+ MB

# %% [markdown]
# ##Finding Answers to the Questions

# %%
#Which ones were the most used city for the three days?
# *mobile

# %%
#Which cities were the most used during business and home hours?
#8mobile

# %%
#
